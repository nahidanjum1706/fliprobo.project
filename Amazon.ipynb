# %%
from bs4 import BeautifulSoup
import requests

# %%
proxies = {
  'http': 'http://134.119.205.253:8080',
  'https': 'http://134.119.205.253:8080',
}

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
r = requests.get('https://www.amazon.in/s?k=smartphones&i=electronics&rh=n%3A976419031%2Cp_36%3A-2000000&dc&page=1', headers=headers)#, proxies=proxies)
content = r.content

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
pages = soup.find('li', {'aria-disabled': 'true'})
pgs = 5

# %%
itemList = []

# %%
for p in range(pgs):
    r1 = requests.get('https://www.amazon.in/s?k=smartphones&i=electronics&rh=n%3A976419031%2Cp_36%3A-2000000&dc&page=' + str(p), headers=headers)#, proxies=proxies)
    content1 = r.content

    soup1 = BeautifulSoup(content, 'html.parser')

    for d in soup.findAll('div', attrs={'class': 's-include-content-margin s-border-bottom s-latency-cf-section'}):

        name = d.find('span', attrs={'class':'a-size-medium a-color-base a-text-normal'})
        price = d.find('span', attrs={'class':'a-offscreen'})
        rating = d.find('span', attrs={'class':'a-icon-alt'})
        imageLink = d.find('img', attrs={'class': 's-image'})

        details = []

        if name is not None:
            details.append(name.text)
        else:
            details.append("unknown-product")

        if price is not None:
            details.append(price.text)
        else:
            details.append('$0')
        
        if rating is not None:
            details.append(rating.text)
        else:
            details.append('-1')

        if imageLink is not None:
            details.append(imageLink['src'])
        else:
            details.append("link-invalid")

        itemList.append(details)

    # print (details)

# %%
for items in itemList:
    print ('------------------------------')
    print ('name: ' + items[0])
    print ('price: ' + items[1])
    print ('rating: ' + items[2])
    print ('image_link: ' + items[3])
    print ('------------------------------')
# Out:
# ------------------------------
# name: Samsung Galaxy M21 (Raven Black, 4GB RAM, 64GB Storage)
# price: ₹13,999
# rating: 4.2 out of 5 stars
# image_link: https://m.media-amazon.com/images/I/71QLvGIAq5L._AC_UY218_.jpg
# ------------------------------
# ------------------------------
# name: OPPO A15s (Dynamic Black, 4GB RAM, 64GB Storage) With No Cost EMI/Additional Exchange Offers
# price: ₹11,490
# rating: 3.2 out of 5 stars
# image_link: https://m.media-amazon.com/images/I/71SvV17lq-L._AC_UY218_.jpg
# ------------------------------
# ------------------------------
# name: Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)
# price: ₹8,999
# rating: 4.0 out of 5 stars
# image_link: https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg
# ------------------------------
# ------------------------------
# name: Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)
# price: ₹13,999
# rating: 4.2 out of 5 stars
# ...
